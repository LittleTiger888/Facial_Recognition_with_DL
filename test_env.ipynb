# %%
#import the libraries
import cv2
import dlib
import face_recognition
import matplotlib.pyplot as plt

#printing the versions
print(cv2.__version__)
print(dlib.__version__)
print(face_recognition.__version__)


image_test = cv2.imread("./images/testing/trump-modi.jpg")

if image_test is None:
    raise FileNotFoundError("Image not found: ./images/testing/trump-modi.jpg")

# OpenCV loads image as BGR, matplotlib expects RGB
image_rgb = cv2.cvtColor(image_test, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,6))
plt.imshow(image_rgb)
plt.title("Image")
plt.axis("off")
plt.show()
# Out:
# /home/aispark/Project/Facial_rec_DL/.venv/lib/python3.12/site-packages/face_recognition_models/__init__.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# 4.13.0
# 20.0.0
# 1.2.3
