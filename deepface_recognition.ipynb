# %%
# -*- coding: utf-8 -*-
from deepface import DeepFace


# detector_backend = "opencv", "ssd", "dlib", "mtcnn", "retinaface"
# model_name = "VGG-Face", "Facenet", "Facenet512", "OpenFace", "DeepFace"
# distance_metric = "cosine", "euclidean", "euclidean_l2"


#face recognition
face_recognition = DeepFace.find(img_path="dataset/testing/modi1.jpg",
                                    db_path="dataset/training",
                                    detector_backend="opencv",
                                    model_name="VGG-Face",
                                    distance_metric="cosine")

print(face_recognition)
# Out:
# 26-01-27 21:50:38 - Found 30 newly added image(s), 0 removed image(s), 0 replaced image(s).
# Finding representations: 100%|██████████| 30/30 [00:04<00:00,  6.16it/s]
# 26-01-27 21:50:42 - There are now 32 representations in ds_model_vggface_detector_opencv_aligned_normalization_base_expand_0.pkl
# 26-01-27 21:50:43 - Searching dataset/testing/modi1.jpg in 32 length datastore
# 26-01-27 21:50:43 - find function duration 5.028010606765747 seconds
# [                       identity                                      hash  \
# 0   dataset/training/modi/6.jpg  7895f3ffbedeeab312518de38eefe2280b7306ae
# 1   dataset/training/modi/5.jpg  a3e1160eaa86bdfb260f7bf48df6b32ef342051a
# 2  dataset/training/modi/10.jpg  bbb751bffd4a4f1b268da8e694bdec3f3920d58b
# 3   dataset/training/modi/1.jpg  e06491148fbfff989d7da362fd031890873c3c04
# 4   dataset/training/modi/8.jpg  47d9495c99480c4473c6936655460fecdddeb8c6
# 5   dataset/training/modi/2.jpg  36140e6d611c54e74b1d4f3aa90e21b862c13b61
# 6   dataset/training/modi/4.jpg  03aef2f49b5b67bb6e47305f9d28c4ba93844109
# 7   dataset/training/modi/7.jpg  1210d8da41bfa33fe33344f9b200eb61c9ecb0bb
# 8   dataset/training/modi/3.jpg  5699893927710580e5854cf21f6042e97e4c48d3
# 9   dataset/training/modi/9.jpg  369ffe240ddcf9a26960cd4736c73a78b30dcc9f
#
#    target_x  target_y  target_w  target_h  threshold  source_x  source_y  \
# 0        69        39       178       178       0.68       517       172
# 1       453        91       255       255       0.68       517       172
# 2        98        22        60        60       0.68       517       172
# 3       169       180       459       459       0.68       517       172
# 4       423       107       318       318       0.68       517       172
# 5       272       189       563       563       0.68       517       172
# 6        66        87       291       291       0.68       517       172
# 7       366       210       405       405       0.68       517       172
# 8       197       121       247       247       0.68       517       172
# 9       292        93       194       194       0.68       517       172
#
#    source_w  source_h  distance  confidence
# 0       335       335  0.268927       93.76
# 1       335       335  0.292990       91.81
# 2       335       335  0.361022       85.35
# 3       335       335  0.387117       82.54
# 4       335       335  0.393191       81.87
# 5       335       335  0.445219       75.85
# 6       335       335  0.503081       68.93
# 7       335       335  0.503164       68.92
# 8       335       335  0.551722       63.27
# 9       335       335  0.568196       61.44  ]
