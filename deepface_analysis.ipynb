# %%
from deepface import DeepFace


#face analysis
face_analysis = DeepFace.analyze(img_path="images/testing/deng.jpg",
                                    actions=['emotion','age','gender','race'])

print(face_analysis)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00, 15.25it/s]
# [{'emotion': {'angry': np.float32(1.286489), 'disgust': np.float32(0.0027948369), 'fear': np.float32(0.07379556), 'happy': np.float32(61.481403), 'sad': np.float32(5.5938897), 'surprise': np.float32(0.0138719175), 'neutral': np.float32(31.547752)}, 'dominant_emotion': 'happy', 'region': {'x': 113, 'y': 86, 'w': 172, 'h': 172, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.94, 'age': 30, 'gender': {'Woman': np.float32(0.055270806), 'Man': np.float32(99.944725)}, 'dominant_gender': 'Man', 'race': {'asian': np.float32(99.992546), 'indian': np.float32(0.001253785), 'black': np.float32(3.3720706e-08), 'white': np.float32(0.00049953087), 'middle eastern': np.float32(1.060442e-08), 'latino hispanic': np.float32(0.0057062227)}, 'dominant_race': 'asian'}]
