# %%
from deepface import DeepFace


#face analysis
face_analysis = DeepFace.analyze(img_path="dataset/testing/modi1.jpg",
                                    actions=['emotion','age','gender','race'])

print(face_analysis)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00, 18.98it/s]
# [{'emotion': {'angry': np.float32(86.42809), 'disgust': np.float32(0.07631239), 'fear': np.float32(4.7377853), 'happy': np.float32(0.40827802), 'sad': np.float32(4.3148427), 'surprise': np.float32(0.6108241), 'neutral': np.float32(3.4238698)}, 'dominant_emotion': 'angry', 'region': {'x': 517, 'y': 172, 'w': 335, 'h': 335, 'left_eye': (734, 308), 'right_eye': (624, 307)}, 'face_confidence': 0.91, 'age': 58, 'gender': {'Woman': np.float32(0.120020844), 'Man': np.float32(99.87998)}, 'dominant_gender': 'Man', 'race': {'asian': np.float32(13.9350395), 'indian': np.float32(4.605087), 'black': np.float32(0.77620035), 'white': np.float32(14.613808), 'middle eastern': np.float32(60.335793), 'latino hispanic': np.float32(5.734074)}, 'dominant_race': 'middle eastern'}]
