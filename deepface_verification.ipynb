# %%
from deepface import DeepFace


# detector_backend = "opencv", "ssd", "dlib", "mtcnn", "retinaface"
# model_name = "VGG-Face", "Facenet", "Facenet512", "OpenFace", "DeepFace"
# distance_metric = "cosine", "euclidean", "euclidean_l2"


#face verification
face_verified = DeepFace.verify(img1_path="dataset/testing/modi1.jpg",
                                    img2_path="dataset/testing/joe1.jpg",
                                    detector_backend="opencv",
                                    model_name="VGG-Face",
                                    distance_metric="cosine")

print(face_verified)
# Out:
# {'verified': False, 'distance': 0.892305, 'threshold': 0.68, 'confidence': 2.95, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 517, 'y': 172, 'w': 335, 'h': 335, 'left_eye': (734, 308), 'right_eye': (624, 307)}, 'img2': {'x': 450, 'y': 148, 'w': 371, 'h': 371, 'left_eye': None, 'right_eye': None}}, 'time': 0.29}
